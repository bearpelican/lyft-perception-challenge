# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
f, ax1, = plt.subplots(1, 2, figsize=(12, 10))
ax1[0].imshow(plt.imread('examples/000043_rgb.png'))
ax1[0].set_title('RGB', fontsize=20)
ax1[1].imshow(plt.imread('examples/000043_seg.png')[:,:,0])
ax1[1].set_title('Segmentation Labels', fontsize=20)
# plt.show()
# Out:
# Text(0.5,1,'Segmentation Labels')

# %%
img_rgb = plt.imread('examples/000043_rgb.png')

# %%
h = 600
t = int(h/3.75)
b = int(h*.9 + h/150)

# %%
plt.imshow(img_rgb[t:b,:,:])

# %%
import cv2

# %%
img_seg = cv2.imread('examples/000043_seg.png')[:,:,2]

# %%
plt.imshow(img_seg==10)

# %%
img_seg_pre = np.zeros_like(img_seg)

# %%
img_seg_pre[(img_seg==7) | (img_seg==6)] = 2

# %%
car = (img_seg==10)

# %%
car[496:, :] = 0

# %%
img_seg_pre[car] = 1

# %%
plt.imshow(img_seg_pre[t:b,:])

# %%
2**5
# Out:
# 32

# %%
f, ax1, = plt.subplots(1, 2, figsize=(12, 10))
ax1[0].imshow(img_rgb[t:b,:,:])
ax1[0].set_title('RGB', fontsize=20)
ax1[1].imshow(img_seg_pre[t:b,:])
ax1[1].set_title('Labels', fontsize=20)
# plt.show()
# Out:
# Text(0.5,1,'Labels')

# %%
plt.figure()
plt.imshow(plt.imread('examples/000043_rgb.png'))
plt.imshow(plt.imread('examples/000043_seg.png')[:,:,0])

# %%
(0.9886+0.8555)/2
# Out:
# 0.92205

# %%
(0.919254*2+0.803204)/3
# Out:
# 0.8805706666666667
